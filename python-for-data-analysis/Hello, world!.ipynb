# %%
print('Hello, world!')
# Out:
# Hello, world!

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot(np.random.randn(50).cumsum())

# %%
a = 5.0
isinstance(a, (int,float))
# Out:
# True

# %%
lst = [1,2,3,4]
lst.pop?

# %%
names = np.array(['Bob','Joe','Will','Bob','Will','Joe','Joe','Brian'])
names
# Out:
# array(['Bob', 'Joe', 'Will', 'Bob', 'Will', 'Joe', 'Joe', 'Brian'],
#       dtype='<U5')

# %%
seq = [7, 2, 3, 7, 5, 6, 0, 1]
seq[-6:-2]
# Out:
# [3, 7, 5, 6]
